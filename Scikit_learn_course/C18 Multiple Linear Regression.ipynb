# %%
import pandas as pd
df=pd.read_csv('winequality-red.csv',sep=';')
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
import matplotlib.pyplot as plt
plt.figure
plt.title('Alcohol against quality')
plt.xlabel('alcohol')
plt.ylabel('quality')
plt.scatter(df['alcohol'],df['quality'])
#k黑色，"."点标记
plt.grid(True)
plt.show()

# %%
plt.figure
plt.title('Alcohol against volatile acidity')
plt.xlabel('volatile acidity')
plt.ylabel('quality')
plt.scatter(df['volatile acidity'],df['quality'])
#k黑色，"."点标记
plt.grid(True)
plt.show()

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
X=df[list(df.columns)[:-1]]
y=df['quality']
#如果有一个DataFrame叫df, df.columns可以得到所有的列标签，同理df.index可以得到所有的行标签
print(list(df.columns))
#val[0:-1]表示第一个元素到倒数第二个元素的切片
#以上可以作为固定写法
# Out:
# ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y)
#X_train,X_test, y_train, y_test =cross_validation.train_test_split(train_data,train_target,test_size=0.3, random_state=0)
#test_size：如果是浮点数，在0-1之间，表示样本占比；如果是整数的话就是样本的数量
#random_state：是随机数的种子。
# train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,y_train)
predict_quality=model.predict(X_test)

# %%
print('R2: %s' % model.score(X_test,y_test))
print(y_test)
#为什么model是(x，y)，因为是评价模型。而metrics是（predicted，y_test），因为评价的是预测点
# Out:
# R2: 0.277737321035
# 1113    6
# 113     6
# 731     5
# 265     7
# 1203    5
# 1265    6
# 67      5
# 1535    6
# 940     7
# 547     6
# 1193    5
# 823     5
# 571     6
# 998     6
# 1398    7
# 659     4
# 70      6
# 271     6
# 1236    6
# 775     5
# 514     7
# 1491    5
# 1087    6
# 149     6
# 363     5
# 643     5
# 422     5
# 396     5
# 679     5
# 1330    6
#        ..
# 965     6
# 1057    5
# 1199    6
# 86      6
# 147     5
# 236     6
# 141     5
# 35      6
# 232     6
# 1133    7
# 546     6
# 1514    6
# 1432    6
# 1374    3
# 450     6
# 1217    6
# 797     7
# 1557    6
# 977     5
# 1584    7
# 681     6
# 1249    6
# 871     5
# 6       5
# 1225    5
# 82      5
# 917     6
# 1122    6
# 413     7
# 206     7
# Name: quality, Length: 400, dtype: int64

# %%
for i,x in enumerate(y_test):
    print('predict_quarlity is %.2f'%predict_quality[i])
    print('True quarlity is %.2f'% x)
# Out:
# predict_quarlity is 5.73
# True quarlity is 6.00
# predict_quarlity is 5.68
# True quarlity is 6.00
# predict_quarlity is 5.39
# True quarlity is 5.00
# predict_quarlity is 6.19
# True quarlity is 7.00
# predict_quarlity is 5.13
# True quarlity is 5.00
# predict_quarlity is 5.56
# True quarlity is 6.00
# predict_quarlity is 5.43
# True quarlity is 5.00
# predict_quarlity is 5.37
# True quarlity is 6.00
# predict_quarlity is 6.63
# True quarlity is 7.00
# predict_quarlity is 6.23
# True quarlity is 6.00
# predict_quarlity is 5.06
# True quarlity is 5.00
# predict_quarlity is 5.29
# True quarlity is 5.00
# predict_quarlity is 5.96
# True quarlity is 6.00
# predict_quarlity is 5.01
# True quarlity is 6.00
# predict_quarlity is 5.41
# True quarlity is 7.00
# predict_quarlity is 5.41
# True quarlity is 4.00
# predict_quarlity is 5.23
# True quarlity is 6.00
# predict_quarlity is 6.29
# True quarlity is 6.00
# predict_quarlity is 5.45
# True quarlity is 6.00
# predict_quarlity is 4.87
# ...

# %%
plt.figure
plt.title('predicted value against true value')
plt.xlabel('predicted value')
plt.ylabel('true value')
plt.axis([2,8,2,8])
plt.scatter(predict_quality,y_test)
#k黑色，"."点标记
plt.grid(True)
plt.show()

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(model,X,y,cv=5)
print(score.mean())
print(score)
# Out:
# 0.290041628842
# [ 0.13200871  0.31858135  0.34955348  0.369145    0.2809196 ]
